# %% [markdown]
# # Equity Investing -  Fundamental Analysis
#
# 1. Scraping key statistical data of Nifty 500 stocks

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Tickers" data-toc-modified-id="Import-Tickers-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Tickers</a></span></li><li><span><a href="#Get-Key-Statistics" data-toc-modified-id="Get-Key-Statistics-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Get Key Statistics</a></span></li></ul></div>

# %%
import time
import urllib
from urllib import request
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import requests

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Import Tickers
#
# [Source](https://www.nseindia.com/products/content/equities/indices/about_indices.htm)
#
# Nifty 500 consists of the following:
#
# * Nifty 50
# * Nifty Next 50
# * Nifty Midcap 150
# * Nift Smallcap 250

# %%
def get_ticker_list(url):
    s=requests.get(url).content
    df_ticker=pd.read_csv(io.StringIO(s.decode('utf-8')))
    
    cols = ['Company Name', 'Industry', 'Symbol']
    df_ticker = df_ticker[cols]
    return(df_ticker)

# %% [raw]
# url = 'https://www.nseindia.com/content/indices/ind_nifty500list.csv'
#
# nifty_500 = get_ticker_list(url)
# display(nifty_500.shape[0])
# display(nifty_500.sample(1))

# %%
url = 'https://www.nseindia.com/content/indices/ind_nifty50list.csv'

nifty_50 = get_ticker_list(url)
nifty_50['category'] = 'Nifty 50'

# %%
url = 'https://www.nseindia.com/content/indices/ind_niftynext50list.csv'

nifty_next_50 = get_ticker_list(url)
nifty_next_50['category'] = 'Nifty Next 50'

# %%
url = 'https://www.nseindia.com/content/indices/ind_niftymidcap150list.csv'

nifty_midcap_150 = get_ticker_list(url)
nifty_midcap_150['category'] = 'Nifty Midcap 150'

# %%
url = 'https://www.nseindia.com/content/indices/ind_niftysmallcap250list.csv'

nifty_smallcap_250 = get_ticker_list(url)
nifty_smallcap_250['category'] = 'Nifty Smallcap 250'

# %% [markdown]
# **Merging**

# %%
df_tickers = pd.DataFrame()
df_tickers = df_tickers.append(nifty_50)
df_tickers = df_tickers.append(nifty_next_50)
df_tickers = df_tickers.append(nifty_midcap_150)
df_tickers = df_tickers.append(nifty_smallcap_250)
df_tickers.columns = ['company', 'industry', 'symbol', 'category']

display(df_tickers.shape[0])
display(df_tickers.sample(1))
# Out:
# 500
#                            company        industry    symbol  \
# 58  Eveready Industries India Ltd.  CONSUMER GOODS  EVEREADY
#
#               category
# 58  Nifty Smallcap 250

# %% [markdown]
# ## Get Key Statistics

# %%
def get_key_stats(stock):
    with urllib.request.urlopen('https://www.screener.in/company/'+stock) as response:
        html = response.read().decode('utf-8').replace(' ', '')      

    market_cap = html.split('MarketCap:\n\n<iclass="fafa-rupee"></i>\n\n<b>')[1].split('</b>')[0]
    
    current_price = html.split('CurrentPrice:\n\n<iclass="fafa-rupee"></i>\n\n<b>')[1].split('</b>')[0]
    
    high_52week = html.split('52weeksHigh/Low\n<iclass="fafa-rupee"></i><b>')[1].split('</b>/<b>')[0]
    
    low_52week = html.split('52weeksHigh/Low\n<iclass="fafa-rupee"></i><b>')[1].split('</b>/<b>')[1].split('</b>')[0]
    
    book_value = html.split('BookValue:\n\n<iclass="fafa-rupee"></i>\n\n<b>')[1].split('</b>')[0]
    
    per = html.split('StockP/E:\n\n<b>')[1].split('</b>')[0]
    
    dividend_yield = html.split('DividendYield:\n\n<b>')[1].split('</b>')[0]
    
    roce = html.split('ROCE:\n\n<b>')[1].split('</b>')[0]
    
    roe = html.split('ROE:\n\n<b>')[1].split('</b>')[0]
    
    sales_growth_3yr = html.split('SalesGrowth(3Yrs):\n\n<b>')[1].split('</b>')[0]
    
    print('Done:', stock)
    return(list([stock, market_cap, current_price,
                 high_52week, low_52week,
                 book_value, per, dividend_yield, roce, roe, sales_growth_3yr]))

# %%
def df_stats(df_stocks):
    cols = ['ticker', 'market_cap', 'current_value', 
            'high_52week', 'low_52week',
            'book_value', 'price_earnings', 
            'dividend_yield', 'roce', 'roe', 'sales_growth_3yr']
    
    df = pd.DataFrame()
    i = 0
    
    for ticker in df_stocks:
        data = pd.DataFrame(get_key_stats(ticker)).T
        time.sleep(1)
        
        df = df.append(data)
        i += 1

    df.columns = cols
    df = df.reset_index(drop=True)
    
    return(df)

# %%
# %%time 
nifty_500_stats = df_stats(df_tickers.symbol)
nifty_500_stats.to_csv('data/nifty_500_stats.csv', 
                       sep=';', encoding='utf-8')
# Out:
# Done: ADANIPORTS
# Done: ASIANPAINT
# Done: AXISBANK
# Done: BAJAJ-AUTO
# Done: BAJFINANCE
# Done: BAJAJFINSV
# Done: BPCL
# Done: BHARTIARTL
# Done: INFRATEL
# Done: CIPLA
# Done: COALINDIA
# Done: DRREDDY
# Done: EICHERMOT
# Done: GAIL
# Done: GRASIM
# Done: HCLTECH
# Done: HDFCBANK
# Done: HEROMOTOCO
# Done: HINDALCO
# Done: HINDPETRO
# Done: HINDUNILVR
# Done: HDFC
# Done: ITC
# Done: ICICIBANK
# Done: IBULHSGFIN
# Done: IOC
# Done: INDUSINDBK
# Done: INFY
# Done: JSWSTEEL
# Done: KOTAKBANK
# Done: LT
# Done: M&M
# Done: MARUTI
# Done: NTPC
# Done: ONGC
# Done: POWERGRID
# Done: RELIANCE
# Done: SBIN
# Done: SUNPHARMA
# Done: TCS
# Done: TATAMOTORS
# Done: TATASTEEL
# Done: TECHM
# Done: TITAN
# Done: UPL
# Done: ULTRACEMCO
# Done: VEDL
# Done: WIPRO
# Done: YESBANK
# Done: ZEEL
# Done: ABB
# Done: ACC
# Done: ABCAPITAL
# Done: AMBUJACEM
# Done: ASHOKLEY
# Done: AUROPHARMA
# Done: DMART
# Done: BANDHANBNK
# Done: BANKBARODA
# Done: BEL
# Done: BHEL
# Done: BIOCON
# Done: BOSCHLTD
# Done: BRITANNIA
# Done: CADILAHC
# Done: COLPAL
# Done: CONCOR
# Done: DLF
# Done: DABUR
# Done: GICRE
# Done: GODREJCP
# Done: HDFCLIFE
# Done: HAVELLS
# Done: HINDZINC
# Done: ICICIGI
# Done: ICICIPRULI
# Done: INDIGO
# Done: L&TFH
# Done: LICHSGFIN
# Done: LUPIN
# Done: MRF
# Done: MARICO
# Done: MOTHERSUMI
# Done: NHPC
# Done: NMDC
# Done: OIL
# Done: OFSS
# Done: PETRONET
# Done: PIDILITIND
# Done: PEL
# Done: PGHH
# Done: SBILIFE
# Done: SHREECEM
# Done: SRTRANSFIN
# Done: SIEMENS
# Done: SAIL
# Done: SUNTV
# Done: NIACL
# Done: MCDOWELL-N
# Done: IDEA
# Done: 3MINDIA
# Done: AIAENG
# Done: AUBANK
# Done: ADANIPOWER
# Done: ADANITRANS
# Done: ABFRL
# Done: AJANTPHARM
# Done: APLLTD
# Done: ALKEM
# Done: AMARAJABAT
# Done: APOLLOHOSP
# Done: APOLLOTYRE
# Done: ASTRAL
# Done: AVANTIFEED
# Done: BAJAJHLDNG
# Done: BALKRISIND
# Done: BANKINDIA
# Done: BATAINDIA
# Done: BERGEPAINT
# Done: BHARATFIN
# Done: BHARATFORG
# Done: BLUEDART
# Done: CRISIL
# Done: CANBK
# Done: CASTROLIND
# Done: CENTRALBK
# Done: CENTURYTEX
# Done: CHOLAFIN
# Done: CUB
# Done: COROMANDEL
# Done: CROMPTON
# Done: CUMMINSIND
# Done: DHFL
# Done: DBL
# Done: DISHTV
# Done: DIVISLAB
# Done: EIHOTEL
# Done: EDELWEISS
# Done: EMAMILTD
# Done: ENDURANCE
# Done: ENGINERSIN
# Done: ESCORTS
# Done: EXIDEIND
# Done: FEDERALBNK
# Done: FINCABLES
# Done: FCONSUMER
# Done: FRETAIL
# Done: GET&D
# Done: GMRINFRA
# Done: GILLETTE
# Done: GSKCONS
# Done: GLAXO
# Done: GLENMARK
# Done: GODREJAGRO
# Done: GODREJIND
# Done: GODREJPROP
# Done: GRAPHITE
# Done: GRUH
# Done: GUJGASLTD
# Done: GSPL
# Done: HEG
# Done: HATSUN
# Done: HEXAWARE
# Done: HAL
# Done: HONAUT
# Done: HUDCO
# Done: ISEC
# Done: IDBI
# Done: IDFCBANK
# Done: IIFL
# Done: IBVENTURES
# Done: INDIANB
# Done: INDHOTEL
# Done: IGL
# Done: NAUKRI
# Done: JMFINANCIL
# Done: JSWENERGY
# Done: JINDALSTEL
# Done: JUBLFOOD
# Done: JUBILANT
# Done: KIOCL
# Done: KRBL
# Done: KANSAINER
# Done: LTTS
# Done: LTI
# Done: MGL
# Done: M&MFIN
# Done: MAHINDCIE
# Done: MANAPPURAM
# Done: MRPL
# Done: MFSL
# Done: MINDTREE
# Done: MOTILALOFS
# Done: MPHASIS
# Done: MUTHOOTFIN
# Done: NATCOPHARM
# Done: NBCC
# Done: NLCINDIA
# Done: NATIONALUM
# Done: OBEROIRLTY
# Done: PCJEWELLER
# Done: PIIND
# Done: PNBHOUSING
# Done: PAGEIND
# Done: PFIZER
# Done: PHOENIXLTD
# Done: PFC
# Done: PRESTIGE
# Done: PNB
# Done: QUESS
# Done: RBLBANK
# Done: RECLTD
# Done: RAJESHEXPO
# Done: RELCAPITAL
# Done: RELINFRA
# Done: RNAM
# Done: RPOWER
# Done: SJVN
# Done: SKFINDIA
# Done: SRF
# Done: SANOFI
# Done: SHRIRAMCIT
# Done: SOLARINDS
# Done: STRTECH
# Done: SPARC
# Done: SUNDARMFIN
# Done: SUNDRMFAST
# Done: SUPREMEIND
# Done: SYMPHONY
# Done: SYNGENE
# Done: TIFIN
# Done: TV18BRDCST
# Done: TVSMOTOR
# Done: TATACHEM
# Done: TATAGLOBAL
# Done: TATAPOWER
# Done: RAMCOCEM
# Done: THERMAX
# Done: THOMASCOOK
# Done: TORNTPHARM
# Done: TORNTPOWER
# Done: TRENT
# Done: UNIONBANK
# Done: UBL
# Done: VGUARD
# Done: VAKRANGEE
# Done: VBL
# Done: VOLTAS
# Done: WABCOINDIA
# Done: WHIRLPOOL
# Done: 8KMILES
# Done: APLAPOLLO
# Done: AARTIIND
# Done: ADVENZYMES
# Done: AEGISCHEM
# Done: AKZOINDIA
# Done: ALBK
# Done: ALLCARGO
# Done: ANDHRABANK
# Done: ASHOKA
# Done: ASTERDM
# Done: ATUL
# Done: BASF
# Done: BEML
# Done: BSE
# Done: BAJAJCORP
# Done: BAJAJELEC
# Done: BALMLAWRIE
# Done: BALRAMCHIN
# Done: BDL
# Done: BIRLACORPN
# Done: BLISSGVS
# Done: BLUESTARCO
# Done: BBTC
# Done: BOMDYEING
# Done: BRIGADE
# Done: CARERATING
# Done: CCL
# Done: CGPOWER
# Done: CANFINHOME
# Done: CAPF
# Done: CAPLIPOINT
# Done: CARBORUNIV
# Done: CEATLTD
# Done: CDSL
# Done: CENTURYPLY
# Done: CERA
# Done: CHAMBLFERT
# Done: CHENNPETRO
# Done: COCHINSHIP
# Done: COFFEEDAY
# Done: CYIENT
# Done: DBCORP
# Done: DCBBANK
# Done: DCMSHRIRAM
# Done: DEEPAKFERT
# Done: DELTACORP
# Done: DEN
# Done: DENABANK
# Done: DCAL
# Done: DIXON
# Done: LALPATHLAB
# Done: DREDGECORP
# Done: EIDPARRY
# Done: ELGIEQUIP
# Done: EQUITAS
# Done: ERIS
# Done: EROSMEDIA
# Done: EVEREADY
# Done: EXCELCROP
# Done: FDC
# Done: FINPIPE
# Done: FSL
# Done: FLFL
# Done: GEPIL
# Done: GHCL
# Done: GVKPIL
# Done: GALAXYSURF
# Done: GDL
# Done: GAYAPROJ
# Done: GODFRYPHLP
# Done: GRANULES
# Done: GESHIP
# Done: GREAVESCOT
# Done: GREENPLY
# Done: GRINDWELL
# Done: GUJALKALI
# Done: GUJFLUORO
# Done: GMDCLTD
# Done: GNFC
# Done: GPPL
# Done: GSFC
# Done: GULFOILLUB
# Done: HCL-INSYS
# Done: HSIL
# Done: HATHWAY
# Done: HEIDELBERG
# Done: HERITGFOOD
# Done: HFCL
# Done: HSCL
# Done: HIMATSEIDE
# Done: HCC
# Done: HINDCOPPER
# Done: IDFC
# Done: IFBIND
# Done: IFCI
# Done: IL&FSTRANS
# Done: IRB
# Done: ITDCEM
# Done: ITI
# Done: INDIACEM
# Done: ITDC
# Done: IBREALEST
# Done: IEX
# Done: IOB
# Done: ICIL
# Done: INDOCO
# Done: INFIBEAM
# Done: INOXLEISUR
# Done: INOXWIND
# Done: INTELLECT
# Done: IPCALAB
# Done: JBCHEPHARM
# Done: JKCEMENT
# Done: JKIL
# Done: JKLAKSHMI
# Done: JKTYRE
# Done: JAGRAN
# Done: JAICORPLTD
# Done: JISLJALEQS
# Done: JPASSOCIAT
# Done: JPPOWER
# Done: J&KBANK
# Done: JETAIRWAYS
# Done: JINDALSAW
# Done: JSLHISAR
# Done: JSL
# Done: JCHAC
# Done: JUSTDIAL
# Done: JYOTHYLAB
# Done: KPRMILL
# Done: KNRCON
# Done: KAJARIACER
# Done: KALPATPOWR
# Done: KTKBANK
# Done: KARURVYSYA
# Done: KSCL
# Done: KEC
# Done: KOLTEPATIL
# Done: LAXMIMACH
# Done: LAKSHVILAS
# Done: LAURUSLABS
# Done: LEMONTREE
# Done: LINDEINDIA
# Done: LUXIND
# Done: MASFIN
# Done: MMTC
# Done: MOIL
# Done: MAGMA
# Done: MHRIL
# Done: MAHLOG
# Done: MANPASAND
# Done: MAXINDIA
# Done: MCLEODRUSS
# Done: MERCK
# Done: MINDACORP
# Done: MINDAIND
# Done: MONSANTO
# Done: NCC
# Done: NESCO
# Done: NIITTECH
# Done: NH
# Done: NFL
# Done: NBVENTURES
# Done: NAVINFLUOR
# Done: NAVKARCORP
# Done: NETWORK18
# Done: NILKAMAL
# Done: OMAXE
# Done: ORIENTCEM
# Done: ORIENTBANK
# Done: PNCINFRA
# Done: PFS
# Done: PTC
# Done: PVR
# Done: PARAGMILK
# Done: PERSISTENT
# Done: PHILIPCARB
# Done: PRAJIND
# Done: PRSMJOHNSN
# Done: RADICO
# Done: RAIN
# Done: RALLIS
# Done: RKFORGE
# Done: RCF
# Done: RAYMOND
# Done: REDINGTON
# Done: RELAXO
# Done: RCOM
# Done: RHFL
# Done: RNAVAL
# Done: REPCOHOME
# Done: RUPA
# Done: SHK
# Done: SREINFRA
# Done: SADBHAV
# Done: SADBHIN
# Done: SCHAEFFLER
# Done: SIS
# Done: SHANKARA
# Done: SHILPAMED
# Done: SCI
# Done: SHOPERSTOP
# Done: RENUKA
# Done: SPTL
# Done: SOBHA
# Done: SONATSOFTW
# Done: SOUTHBANK
# Done: STARCEMENT
# Done: STAR
# Done: SUDARSCHEM
# Done: SUNTECK
# Done: SUVEN
# Done: SUZLON
# Done: SWANENERGY
# Done: SYNDIBANK
# Done: TTKPRESTIG
# Done: TVTODAY
# Done: TVSSRICHAK
# Done: TAKE
# Done: TNPL
# Done: TATACOFFEE
# Done: TATAELXSI
# Done: TATAINVEST
# Done: TATASPONGE
# Done: TEAMLEASE
# Done: TEXRAIL
# Done: THYROCARE
# Done: TIMETECHNO
# Done: TIMKEN
# Done: TRIDENT
# Done: TIINDIA
# Done: UCOBANK
# Done: UFLEX
# Done: UJJIVAN
# Done: UNICHEMLAB
# Done: VMART
# Done: VIPIND
# Done: VRLLOG
# Done: WABAG
# Done: VTL
# Done: VENKEYS
# Done: VIJAYABANK
# Done: VINATIORGA
# Done: WELCORP
# Done: WELSPUNIND
# Done: WOCKPHARMA
# Done: ZENSARTECH
# Done: ZYDUSWELL
# Done: ECLERX
# CPU times: user 23.1 s, sys: 1.77 s, total: 24.9 s
# Wall time: 27min 45s

# %%
nifty_500_stats = pd.read_csv('data/nifty_500_stats.csv', 
                              sep=';', 
                              encoding='utf-8', 
                              thousands=',',
                              na_values='None'
                             )

del nifty_500_stats['Unnamed: 0']
nifty_500_stats = nifty_500_stats.apply(pd.to_numeric, errors='ignore')
nifty_500_stats = nifty_500_stats.rename(columns = {'ticker':'symbol'})

# %%
df_nifty_500 = pd.merge(df_tickers, nifty_500_stats, on='symbol')

display(df_nifty_500.shape)
df_nifty_500.sample(3)
# Out:
# (500, 14)
#                                  company                  industry  symbol  \
# 169                   IIFL Holdings Ltd.        FINANCIAL SERVICES    IIFL
# 183         L&T Technology Services Ltd.                        IT    LTTS
# 440  Reliance Naval and Engineering Ltd.  INDUSTRIAL MANUFACTURING  RNAVAL
#
#                category  market_cap  current_value  high_52week  low_52week  \
# 169    Nifty Midcap 150     14457.0         453.10        872.7       341.0
# 183    Nifty Midcap 150     17396.0        1673.00       1852.5       815.1
# 440  Nifty Smallcap 250      1044.0          14.15         72.6        11.0
#
#      book_value  price_earnings  dividend_yield   roce     roe  \
# 169       46.47           78.05            1.10  13.60   13.83
# 183      187.81           28.88            0.94  38.98   28.00
# 440       -6.61             NaN            0.00  -3.08 -114.00
#
#      sales_growth_3yr
# 169             13.01
# 183             11.05
# 440            -26.12

# %%
df_nifty_500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 14 columns):
# company             500 non-null object
# industry            500 non-null object
# symbol              500 non-null object
# category            500 non-null object
# market_cap          500 non-null float64
# current_value       500 non-null float64
# high_52week         497 non-null float64
# low_52week          497 non-null float64
# book_value          500 non-null float64
# price_earnings      455 non-null float64
# dividend_yield      500 non-null float64
# roce                500 non-null float64
# roe                 498 non-null float64
# sales_growth_3yr    491 non-null float64
# dtypes: float64(10), object(4)
# memory usage: 58.6+ KB

# %%
df_nifty_500.to_csv('data/nifty_500_stats.csv', 
                       sep=';', encoding='utf-8')
